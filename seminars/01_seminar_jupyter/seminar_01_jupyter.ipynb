# %% [markdown]
# # Семинар 1. Jupyter Notebook. Практика по визуализации
#
# **Имя:** [Ваше имя]
# **Дата:** [Дата семинара]
#
# ---
#
# **Цель:** освоить работу в среде Google Colab / Jupyter Notebook, научиться использовать NumPy и Matplotlib для численных вычислений и визуализации.
#
# **Инструкции:**
# - Заполняйте ячейки с пометкой `# ВАШ КОД` своим решением
# - Не удаляйте Markdown-ячейки с заданиями
# - После выполнения всех заданий перезапустите ядро и выполните все ячейки сверху вниз (Runtime → Restart and run all), чтобы убедиться в воспроизводимости
# - Итоговый ноутбук с кодом, графиками и пояснениями — основной артефакт для защиты

# %% [markdown]
# ---
# ## Задача 1. Знакомство с Google Colab

# %% [markdown]
# ### 1.1. Выведите `"Hello, Colab!"`

# %%
# ВАШ КОД

# %% [markdown]
# ### 1.2. Версия Python и предустановленные пакеты

# %%
import sys
print(sys.version)

# %%
# !pip list | head -20

# %% [markdown]
# ### 1.3. Перезапуск ядра
#
# После выполнения ячеек выше перезапустите ядро (Runtime → Restart runtime) и выполните все ячейки заново (Runtime → Run all). Убедитесь, что ноутбук воспроизводим сверху вниз.

# %% [markdown]
# ---
# ## Задача 2. NumPy: создание массивов и базовые операции

# %%
import numpy as np

# %% [markdown]
# ### 2.1. Создайте одномерный массив из списка `[1, 4, 9, 16, 25]` и выведите `shape` и `dtype`

# %%
# ВАШ КОД

# %% [markdown]
# ### 2.2. Создайте массив из 100 точек на отрезке $[0, 2\pi]$ с помощью `np.linspace`; выведите первые 5 и последние 5 элементов

# %%
# ВАШ КОД

# %% [markdown]
# ### 2.3. Поэлементные операции: возведите массив в квадрат, извлеките корень, сложите два массива одинаковой длины

# %%
# ВАШ КОД

# %% [markdown]
# ### 2.4. Broadcasting: создайте `a = np.arange(5)` и прибавьте скаляр `10`

# %%
# ВАШ КОД

# %% [markdown]
# **Объяснение:** [Опишите, что такое broadcasting и что произошло при сложении массива и скаляра]

# %% [markdown]
# ### 2.5. Создайте двумерный массив 3×4, заполненный значениями $a_{ij} = i + j$

# %%
# ВАШ КОД
# Подсказка: используйте np.zeros((3, 4)) и broadcasting или np.arange

# %% [markdown]
# ---
# ## Задача 3. Первый график: функция одной переменной

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3.1. Постройте график $y = \sin(x)$ на отрезке $[0, 2\pi]$ (200 точек)

# %%
# ВАШ КОД

# %% [markdown]
# ### 3.2. Добавьте $y = \cos(x)$ на тот же график с подписями осей, заголовком и легендой

# %%
# ВАШ КОД

# %% [markdown]
# ### 3.3. Включите сетку и сохраните график в файл `sin_cos.png`

# %%
# ВАШ КОД
# Подсказка: plt.grid(True), plt.savefig("sin_cos.png", dpi=150)

# %% [markdown]
# **Описание:** [Опишите, как меняется поведение функций $\sin$ и $\cos$ на заданном отрезке]

# %% [markdown]
# ---
# ## Задача 4. Оформление и стилизация графиков

# %% [markdown]
# ### 4.1. Постройте график $y = e^{-x/3} \cdot \sin(2x)$ на $[0, 4\pi]$
#
# Задайте цвет, толщину (`linewidth`) и стиль линии (`linestyle`).

# %%
# ВАШ КОД

# %% [markdown]
# ### 4.2. Отметьте точки пересечения с осью $x$ маркерами и подпишите одну из них с помощью `plt.annotate`

# %%
# ВАШ КОД
# Подсказка: нули sin(2x) — это x = k*pi/2

# %% [markdown]
# ### 4.3. Измените размер фигуры (`figsize=(10, 4)`) и примените стиль оформления

# %%
# Посмотрите доступные стили
print(plt.style.available)

# %%
# ВАШ КОД
# Примените стиль через plt.style.use(...) и перестройте график

# %% [markdown]
# **Выбранный стиль:** [название стиля]

# %% [markdown]
# ---
# ## Задача 5. Subplots: сравнение функций
#
# Создайте фигуру 2×2 с графиками:
# - $y = x^2$
# - $y = x^3 - 3x$
# - $y = \sin(x) / x$ (обработайте $x = 0$)
# - $y = \ln(1 + x^2)$

# %%
# ВАШ КОД
# Подсказка: fig, axes = plt.subplots(2, 2, figsize=(10, 8))
# Для sin(x)/x можно использовать np.sinc(x/np.pi) или ограничить область

# %% [markdown]
# **Описание функций:**
# - $y = x^2$: [чётность, экстремумы, асимптотики]
# - $y = x^3 - 3x$: [чётность, экстремумы]
# - $y = \sin(x)/x$: [поведение в нуле, асимптотики]
# - $y = \ln(1 + x^2)$: [чётность, поведение]

# %% [markdown]
# ---
# ## Задача 6. Scatter plot и другие типы графиков

# %% [markdown]
# ### 6.1. Scatter plot: 200 случайных точек с цветом по значению $y$

# %%
# ВАШ КОД
# x = np.random.randn(200)
# y = 0.5 * x + np.random.randn(200) * 0.3
# plt.scatter(..., c=y, cmap='...')

# %% [markdown]
# ### 6.2. Столбчатая диаграмма: $\sin(k)$ для $k = 1, 2, \ldots, 10$

# %%
# ВАШ КОД

# %% [markdown]
# ### 6.3. Stem-диаграмма: первые 20 членов $a_n = (-1)^n / n$

# %%
# ВАШ КОД

# %% [markdown]
# ### 6.4. Разместите все три графика на одной фигуре (1×3) и сохраните

# %%
# ВАШ КОД

# %% [markdown]
# ---
# ## Задача 7. Гистограммы и визуализация распределений

# %% [markdown]
# ### 7.1. Гистограмма нормального распределения (10 000 чисел, 50 bins) с теоретической плотностью

# %%
# ВАШ КОД
# Подсказка: plt.hist(data, bins=50, density=True)
# Теоретическая плотность: (1/np.sqrt(2*np.pi)) * np.exp(-x**2 / 2)

# %% [markdown]
# ### 7.2. Три гистограммы в subplots (1×3): нормальное, равномерное, экспоненциальное распределения

# %%
# ВАШ КОД

# %% [markdown]
# **Объяснение:** [Что такое плотность вероятности? Зачем нужен параметр `density=True`?]

# %% [markdown]
# ---
# ## Задача 8. Визуализация функций двух переменных

# %% [markdown]
# ### 8.1. Создайте сетку на $[-3, 3] \times [-3, 3]$ (шаг 0.05) и вычислите $z = \sin(x^2 + y^2)$

# %%
# ВАШ КОД
# Подсказка: X, Y = np.meshgrid(np.arange(-3, 3, 0.05), np.arange(-3, 3, 0.05))

# %% [markdown]
# ### 8.2. Постройте `imshow` и `contourf` для $z = \sin(x^2 + y^2)$

# %%
# ВАШ КОД
# Подсказка: plt.imshow(Z, extent=[-3, 3, -3, 3], origin='lower', cmap='viridis')

# %% [markdown]
# ### 8.3. Повторите для $z = \cos(x) \cdot \sin(y)$; разместите все 4 изображения на фигуре 2×2

# %%
# ВАШ КОД

# %% [markdown]
# **Объяснение:** [Как линии уровня связаны с понятием градиента?]

# %% [markdown]
# ---
# ## Задача 9. Параметрические кривые и полярные координаты

# %% [markdown]
# ### 9.1. Фигура Лиссажу: $x(t) = \sin(3t)$, $y(t) = \sin(4t)$, $t \in [0, 2\pi]$
#
# Раскрасьте кривую по параметру $t$.

# %%
# ВАШ КОД

# %% [markdown]
# ### 9.2. Спираль Архимеда: $r = a + b\theta$ в полярных координатах

# %%
# ВАШ КОД
# Подсказка: используйте plt.subplot(projection='polar')
# или вычислите x = r*cos(theta), y = r*sin(theta)

# %% [markdown]
# ### 9.3. Кардиоида: $r = 1 + \cos\theta$ в полярных координатах

# %%
# ВАШ КОД

# %% [markdown]
# ### 9.4. Разместите все три графика (Лиссажу, спираль, кардиоида) на одной фигуре

# %%
# ВАШ КОД

# %% [markdown]
# **Объяснение:** [Что такое параметрическое задание кривой? Что такое полярные координаты?]

# %% [markdown]
# ---
# ## Бонусные задачи (необязательно)

# %% [markdown]
# ### Бонус 1. 3D-поверхность $z = \sin(\sqrt{x^2 + y^2})$
#
# Используйте `mpl_toolkits.mplot3d`, `ax.plot_surface`, подберите `cmap` и угол обзора (`ax.view_init`).

# %%
# ВАШ КОД (бонус)

# %% [markdown]
# ### Бонус 2. Анимация «бегущей волны» $y(x, t) = \sin(x - t)$
#
# Используйте `matplotlib.animation.FuncAnimation`, сохраните как GIF.

# %%
# ВАШ КОД (бонус)

# %% [markdown]
# ### Бонус 3. Фрактал Мандельброта
#
# Реализуйте вычисление множества Мандельброта на сетке комплексных чисел с помощью NumPy (без явных циклов по точкам). Визуализируйте через `plt.imshow`.

# %%
# ВАШ КОД (бонус)

# %% [markdown]
# **Объяснение:** [Что такое множество Мандельброта? Как работает итерационная формула $z_{n+1} = z_n^2 + c$?]
